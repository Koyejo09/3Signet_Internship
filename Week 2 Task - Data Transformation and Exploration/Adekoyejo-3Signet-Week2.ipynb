# %% [markdown]
# # 3Signet Deliverable 2 -Adekoyejo Dada

# %%
#Import the sqlite3 module and other libraries

import sqlite3
import pandas as pd
import os

# %%
#Connect to an SQlite Database
conn = sqlite3.connect('C:/Users/Adekoyejo.dada/Desktop/3signet/Database_Link/adventure_works_db.db')
cursor = conn.cursor()

# %%
#Query the database and load the results into a Pandas Dataframe
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('AdventureWorks_Sales_2015',), ('AdventureWorks_Sales_2016',), ('AdventureWorks_Sales_2017',), ('AdventureWorks_Customers',), ('sqlite_sequence',), ('AdventureWorks_Product_Categories',), ('AdventureWorks_Product_Subcategories',), ('AdventureWorks_Products',), ('AdventureWorks_Territories',), ('merged_AdventuresWorks_sales',), ('AdventureWorks_Returns',), ('AdventureWorks_Calendar',), ('Merged_AdventureWorks_DataandAdventureWorks_Products',), ('Merged_AdventureWorks_Data_ProductsandAdventureWorks_Product_Subcategories',)]

# %%
# Check if the table contains data
cursor.execute("SELECT COUNT(*) FROM AdventureWorks_Calendar")
row_count = cursor.fetchone()[0]
print(f"Number of rows: {row_count}")
# Out:
# Number of rows: 912

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Sales_2015;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  1/1/2015   9/21/2001     SO45080         332        14657             1
# 1  1/1/2015   12/5/2001     SO45079         312        29255             4
# 2  1/1/2015  10/29/2001     SO45082         350        11455             9
# 3  1/1/2015  11/16/2001     SO45081         338        26782             6
# 4  1/2/2015  12/15/2001     SO45083         312        14947            10
#
#    OrderLineItem  OrderQuantity
# 0              1              1
# 1              1              1
# 2              1              1
# 3              1              1
# 4              1              1

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# OrderDate        0
# StockDate        0
# OrderNumber      0
# ProductKey       0
# CustomerKey      0
# TerritoryKey     0
# OrderLineItem    0
# OrderQuantity    0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [OrderDate, StockDate, OrderNumber, ProductKey, CustomerKey, TerritoryKey, OrderLineItem, OrderQuantity]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['OrderLineItem'] = pd.to_numeric(df['OrderLineItem'], errors = 'coerce')
df['ProductKey'] = pd.to_numeric(df['ProductKey'], errors = 'coerce')
df['TerritoryKey'] = pd.to_numeric(df['TerritoryKey'], errors = 'coerce')
df['OrderQuantity'] = pd.to_numeric(df['OrderQuantity'], errors = 'coerce')
#Convert Date types
df['StockDate'] = pd.to_datetime(df['StockDate'], errors='coerce')
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# %%
# Check for unique values in column (OrderNumber)
unique_values = df['OrderNumber'].is_unique
print(f"OrderNumber has unique values: {unique_values}")
# Out:
# OrderNumber has unique values: True

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Sales_2016;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#     OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  01/01/2016  10/17/2002     SO48797         385        14335             1
# 1  01/01/2016   9/30/2002     SO48802         383        24923             9
# 2  01/01/2016  11/29/2002     SO48801         326        15493             1
# 3  01/01/2016  11/16/2002     SO48799         352        26708             4
# 4  01/01/2016  12/16/2002     SO48798         369        23332             9
#
#    OrderLineItem  OrderQuantity
# 0              1              1
# 1              1              1
# 2              1              1
# 3              1              1
# 4              1              1

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# OrderDate        0
# StockDate        0
# OrderNumber      0
# ProductKey       0
# CustomerKey      0
# TerritoryKey     0
# OrderLineItem    0
# OrderQuantity    0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [OrderDate, StockDate, OrderNumber, ProductKey, CustomerKey, TerritoryKey, OrderLineItem, OrderQuantity]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['OrderLineItem'] = pd.to_numeric(df['OrderLineItem'], errors = 'coerce')
df['ProductKey'] = pd.to_numeric(df['ProductKey'], errors = 'coerce')
df['TerritoryKey'] = pd.to_numeric(df['TerritoryKey'], errors = 'coerce')
df['OrderQuantity'] = pd.to_numeric(df['OrderQuantity'], errors = 'coerce')
#Convert Date types
df['StockDate'] = pd.to_datetime(df['StockDate'], errors='coerce')
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# %%
# Check for unique values in column (OrderNumber)
unique_values = df['OrderNumber'].is_unique
print(f"OrderNumber has unique values: {unique_values}")
#The Output signifies that the ordernumber is false but this needs not be changed because Multiple products can be placed on the same order
# Out:
# OrderNumber has unique values: False

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Sales_2017;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#     OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  01/01/2017  12/13/2003     SO61285         529        23791             1
# 1  01/01/2017   9/24/2003     SO61285         214        23791             1
# 2  01/01/2017  09/04/2003     SO61285         540        23791             1
# 3  01/01/2017   9/28/2003     SO61301         529        16747             1
# 4  01/01/2017  10/21/2003     SO61301         377        16747             1
#
#    OrderLineItem  OrderQuantity
# 0              2              2
# 1              3              1
# 2              1              1
# 3              2              2
# 4              1              1

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# OrderDate        0
# StockDate        0
# OrderNumber      0
# ProductKey       0
# CustomerKey      0
# TerritoryKey     0
# OrderLineItem    0
# OrderQuantity    0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [OrderDate, StockDate, OrderNumber, ProductKey, CustomerKey, TerritoryKey, OrderLineItem, OrderQuantity]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['OrderLineItem'] = pd.to_numeric(df['OrderLineItem'], errors = 'coerce')
df['ProductKey'] = pd.to_numeric(df['ProductKey'], errors = 'coerce')
df['TerritoryKey'] = pd.to_numeric(df['TerritoryKey'], errors = 'coerce')
df['OrderQuantity'] = pd.to_numeric(df['OrderQuantity'], errors = 'coerce')
#Convert Date types
df['StockDate'] = pd.to_datetime(df['StockDate'], errors='coerce')
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# %%
# Check for unique values in column (OrderNumber)
unique_values = df['OrderNumber'].is_unique
print(f"OrderNumber has unique values: {unique_values}") 

#The Output signifies that the ordernumber is false but this needs not be changed because Multiple products can be placed on the same order
# Out:
# OrderNumber has unique values: False

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Customers;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0        11000    MR.        JON     YANG  1966-04-08             M      M
# 1        11001    MR.     EUGENE    HUANG  1965-05-14             S      M
# 2        11002    MR.      RUBEN   TORRES  1965-08-12             M      M
# 3        11003    MS.    CHRISTY      ZHU  1968-02-15             S      F
# 4        11004   MRS.  ELIZABETH  JOHNSON  1968-08-08             S      F
#
#                      EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@adventure-works.com      $90,000              2      Bachelors
# 1    eugene10@adventure-works.com      $60,000              3      Bachelors
# 2     ruben35@adventure-works.com      $60,000              3      Bachelors
# 3   christy12@adventure-works.com      $70,000              0      Bachelors
# 4  elizabeth5@adventure-works.com      $80,000              5      Bachelors
#
#      Occupation HomeOwner
# ...

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# CustomerKey       0
# Prefix            0
# FirstName         0
# LastName          0
# BirthDate         0
# MaritalStatus     0
# Gender            0
# EmailAddress      0
# AnnualIncome      0
# TotalChildren     0
# EducationLevel    0
# Occupation        0
# HomeOwner         0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [CustomerKey, Prefix, FirstName, LastName, BirthDate, MaritalStatus, Gender, EmailAddress, AnnualIncome, TotalChildren, EducationLevel, Occupation, HomeOwner]
# Index: []

# %%
df_encoded = pd.get_dummies(df, columns=['MaritalStatus', 'Gender','HomeOwner'], drop_first=True)

# %%
#Data Validation
# Check for unique values in column 
unique_values = df['CustomerKey'].is_unique
print(f"CustomerKey has unique values: {unique_values}")
# Out:
# CustomerKey has unique values: True

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['AnnualIncome'] = pd.to_numeric(df['AnnualIncome'], errors = 'coerce')
df['TotalChildren'] = pd.to_numeric(df['TotalChildren'], errors = 'coerce')

#Convert Date types
df['BirthDate'] = pd.to_datetime(df['BirthDate'], errors='coerce')

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Product_Categories;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    ProductCategoryKey CategoryName
# 0                   1        Bikes
# 1                   2   Components
# 2                   3     Clothing
# 3                   4  Accessories

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# ProductCategoryKey    0
# CategoryName          0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [ProductCategoryKey, CategoryName]
# Index: []

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Product_SubCategories;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    ProductSubcategoryKey  SubcategoryName  ProductCategoryKey
# 0                      1   Mountain Bikes                   1
# 1                      2       Road Bikes                   1
# 2                      3    Touring Bikes                   1
# 3                      4       Handlebars                   2
# 4                      5  Bottom Brackets                   2

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# ProductSubcategoryKey    0
# SubcategoryName          0
# ProductCategoryKey       0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [ProductSubcategoryKey, SubcategoryName, ProductCategoryKey]
# Index: []

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Products;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    ProductKey  ProductSubcategoryKey ProductSKU              ProductName  \
# 0         214                     31  HL-U509-R    Sport-100 Helmet, Red
# 1         215                     31    HL-U509  Sport-100 Helmet, Black
# 2         218                     23  SO-B909-M   Mountain Bike Socks, M
# 3         219                     23  SO-B909-L   Mountain Bike Socks, L
# 4         220                     31  HL-U509-B   Sport-100 Helmet, Blue
#
#              ModelName                                 ProductDescription  \
# 0            Sport-100  Universal fit, well-vented, lightweight , snap...
# 1            Sport-100  Universal fit, well-vented, lightweight , snap...
# 2  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 3  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 4            Sport-100  Universal fit, well-vented, lightweight , snap...
#
#   ProductColor ProductSize ProductStyle  ProductCost  ProductPrice
# ...

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# ProductKey               0
# ProductSubcategoryKey    0
# ProductSKU               0
# ProductName              0
# ModelName                0
# ProductDescription       0
# ProductColor             0
# ProductSize              0
# ProductStyle             0
# ProductCost              0
# ProductPrice             0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [ProductKey, ProductSubcategoryKey, ProductSKU, ProductName, ModelName, ProductDescription, ProductColor, ProductSize, ProductStyle, ProductCost, ProductPrice]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['ProductKey'] = pd.to_numeric(df['ProductKey'], errors = 'coerce')
df['ProductSubcategoryKey'] = pd.to_numeric(df['ProductSubcategoryKey'], errors = 'coerce')
df['ProductCost'] = pd.to_numeric(df['ProductCost'], errors = 'coerce')
df['ProductPrice'] = pd.to_numeric(df['ProductPrice'], errors = 'coerce')

# %%
# Check for unique values in column 
unique_values = df['ProductKey'].is_unique
print(f"ProductKey has unique values: {unique_values}")
# Out:
# ProductKey has unique values: True

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Territories;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    SalesTerritoryKey     Region        Country      Continent
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# SalesTerritoryKey    0
# Region               0
# Country              0
# Continent            0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [SalesTerritoryKey, Region, Country, Continent]
# Index: []

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['SalesTerritoryKey'].is_unique
print(f"SalesTerritoryKey has unique values: {unique_values}")
# Out:
# SalesTerritoryKey has unique values: True

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Returns;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0  1/18/2015             9         312               1
# 1  1/18/2015            10         310               1
# 2  1/21/2015             8         346               1
# 3  1/22/2015             4         311               1
# 4   2/2/2015             6         312               1

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# ReturnDate        0
# TerritoryKey      0
# ProductKey        0
# ReturnQuantity    0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [ReturnDate, TerritoryKey, ProductKey, ReturnQuantity]
# Index: []

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['ProductKey'].is_unique
print(f"ProductKey has unique values: {unique_values}") #The output being false does not negate wrong data as multiple customers can buy the same product
# Out:
# ProductKey has unique values: False

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['TerritoryKey'].is_unique
print(f"TerritoryKey has unique values: {unique_values}") #The output is false does not negate wrong data as multiple products can be bought from the same territory
# Out:
# TerritoryKey has unique values: False

# %%
# Query the data from a table
query = "SELECT * FROM merged_AdventuresWorks_sales;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  1/1/2015   9/21/2001     SO45080         332        14657             1
# 1  1/1/2015   12/5/2001     SO45079         312        29255             4
# 2  1/1/2015  10/29/2001     SO45082         350        11455             9
# 3  1/1/2015  11/16/2001     SO45081         338        26782             6
# 4  1/2/2015  12/15/2001     SO45083         312        14947            10
#
#    OrderLineItem  OrderQuantity  ROW_ID
# 0              1              1       1
# 1              1              1       2
# 2              1              1       3
# 3              1              1       4
# 4              1              1       5

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# OrderDate        0
# StockDate        0
# OrderNumber      0
# ProductKey       0
# CustomerKey      0
# TerritoryKey     0
# OrderLineItem    0
# OrderQuantity    0
# ROW_ID           0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [OrderDate, StockDate, OrderNumber, ProductKey, CustomerKey, TerritoryKey, OrderLineItem, OrderQuantity, ROW_ID]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['ProductKey'] = pd.to_numeric(df['ProductKey'], errors = 'coerce')
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['TerritoryKey'] = pd.to_numeric(df['TerritoryKey'], errors = 'coerce')
#Convert Date types
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')
df['StockDate'] = pd.to_datetime(df['StockDate'], errors='coerce')

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['ProductKey'].is_unique
print(f"ProductKey has unique values: {unique_values}") #Different customers buy the same product
# Out:
# ProductKey has unique values: False

# %%
# Query the data from a table
query = "SELECT * FROM Merged_AdventureWorks_DataandAdventureWorks_Products;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  CustomerKey  TerritoryKey  OrderLineItem  \
# 0  1/1/2015   9/21/2001     SO45080        14657             1              1
# 1  1/1/2015   12/5/2001     SO45079        29255             4              1
# 2  1/1/2015  10/29/2001     SO45082        11455             9              1
# 3  1/1/2015  11/16/2001     SO45081        26782             6              1
# 4  1/2/2015  12/15/2001     SO45083        14947            10              1
#
#    OrderQuantity  ROW_ID  ProductSubcategoryKey  ProductSKU  \
# 0              1       1                      2  BK-R50B-58
# 1              1       2                      2  BK-R93R-48
# 2              1       3                      1  BK-M82B-44
# 3              1       4                      2  BK-R50B-44
# 4              1       5                      2  BK-R93R-48
#
#               ProductName     ModelName  \
# 0      Road-650 Black, 58      Road-650
# 1        Road-150 Red, 48      Road-150
# ...

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# OrderDate                0
# StockDate                0
# OrderNumber              0
# CustomerKey              0
# TerritoryKey             0
# OrderLineItem            0
# OrderQuantity            0
# ROW_ID                   0
# ProductSubcategoryKey    0
# ProductSKU               0
# ProductName              0
# ModelName                0
# ProductDescription       0
# ProductColor             0
# ProductSize              0
# ProductStyle             0
# ProductCost              0
# ProductPrice             0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [OrderDate, StockDate, OrderNumber, CustomerKey, TerritoryKey, OrderLineItem, OrderQuantity, ROW_ID, ProductSubcategoryKey, ProductSKU, ProductName, ModelName, ProductDescription, ProductColor, ProductSize, ProductStyle, ProductCost, ProductPrice]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['OrderLineItem'] = pd.to_numeric(df['OrderLineItem'], errors = 'coerce')
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['TerritoryKey'] = pd.to_numeric(df['TerritoryKey'], errors = 'coerce')
df['OrderQuantity'] = pd.to_numeric(df['OrderQuantity'], errors = 'coerce')
df['ROW_ID'] = pd.to_numeric(df['ROW_ID'], errors = 'coerce')
df['ProductSubcategoryKey'] = pd.to_numeric(df['ProductSubcategoryKey'], errors = 'coerce')
df['ProductCost'] = pd.to_numeric(df['ProductCost'], errors = 'coerce')
df['ProductPrice'] = pd.to_numeric(df['ProductPrice'], errors = 'coerce')
#Convert Date types
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')
df['StockDate'] = pd.to_datetime(df['StockDate'], errors='coerce')

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['CustomerKey'].is_unique
print(f"CustomerKey has unique values: {unique_values}")
# Out:
# CustomerKey has unique values: False

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['OrderLineItem'].is_unique
print(f"OrderLineItem has unique values: {unique_values}")
# Out:
# OrderLineItem has unique values: False

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['TerritoryKey'].is_unique
print(f"TerritoryKey has unique values: {unique_values}")
# Out:
# TerritoryKey has unique values: False

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['ProductSubcategoryKey'].is_unique
print(f"ProductSubcategoryKey has unique values: {unique_values}")
# Out:
# ProductSubcategoryKey has unique values: False

# %%
# Query the data from a table
query = "SELECT * FROM Merged_AdventureWorks_Data_ProductsandAdventureWorks_Product_Subcategories;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  CustomerKey  TerritoryKey  OrderLineItem  \
# 0  1/1/2015   9/21/2001     SO45080        14657             1              1
# 1  1/1/2015   12/5/2001     SO45079        29255             4              1
# 2  1/1/2015  10/29/2001     SO45082        11455             9              1
# 3  1/1/2015  11/16/2001     SO45081        26782             6              1
# 4  1/2/2015  12/15/2001     SO45083        14947            10              1
#
#    OrderQuantity  ROW_ID  ProductSKU             ProductName     ModelName  \
# 0              1       1  BK-R50B-58      Road-650 Black, 58      Road-650
# 1              1       2  BK-R93R-48        Road-150 Red, 48      Road-150
# 2              1       3  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3              1       4  BK-R50B-44      Road-650 Black, 44      Road-650
# 4              1       5  BK-R93R-48        Road-150 Red, 48      Road-150
#
# ...

# %%
#Data preprocessing
#Check for missing values

missing_data = df.isnull().sum()
print(missing_data)
# Out:
# OrderDate             0
# StockDate             0
# OrderNumber           0
# CustomerKey           0
# TerritoryKey          0
# OrderLineItem         0
# OrderQuantity         0
# ROW_ID                0
# ProductSKU            0
# ProductName           0
# ModelName             0
# ProductDescription    0
# ProductColor          0
# ProductSize           0
# ProductStyle          0
# ProductCost           0
# ProductPrice          0
# SubcategoryName       0
# ProductCategoryKey    0
# dtype: int64

# %%
#Removing Duplicates
#Check for duplicates

duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [OrderDate, StockDate, OrderNumber, CustomerKey, TerritoryKey, OrderLineItem, OrderQuantity, ROW_ID, ProductSKU, ProductName, ModelName, ProductDescription, ProductColor, ProductSize, ProductStyle, ProductCost, ProductPrice, SubcategoryName, ProductCategoryKey]
# Index: []

# %%
#Data Validation
#Check datatypes

#Convert datatypes
df['OrderLineItem'] = pd.to_numeric(df['OrderLineItem'], errors = 'coerce')
df['CustomerKey'] = pd.to_numeric(df['CustomerKey'], errors = 'coerce')
df['TerritoryKey'] = pd.to_numeric(df['TerritoryKey'], errors = 'coerce')
df['OrderQuantity'] = pd.to_numeric(df['OrderQuantity'], errors = 'coerce')
df['ROW_ID'] = pd.to_numeric(df['ROW_ID'], errors = 'coerce')
df['ProductCategoryKey'] = pd.to_numeric(df['ProductCategoryKey'], errors = 'coerce')
df['ProductCost'] = pd.to_numeric(df['ProductCost'], errors = 'coerce')
df['ProductPrice'] = pd.to_numeric(df['ProductPrice'], errors = 'coerce')
#Convert Date types
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')
df['StockDate'] = pd.to_datetime(df['StockDate'], errors='coerce')

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['CustomerKey'].is_unique
print(f"CustomerKey has unique values: {unique_values}") #Same customers can buy multiple products
# Out:
# CustomerKey has unique values: False

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['TerritoryKey'].is_unique
print(f"TerritoryKey has unique values: {unique_values}") #Multiple customers can buy from the same territories
# Out:
# TerritoryKey has unique values: False

# %%
# Data Validation
# Check for unique values in column 
unique_values = df['ProductCategoryKey'].is_unique
print(f"ProductCategoryKey has unique values: {unique_values}") #Multiple customers can patronise the ProductCategory
# Out:
# ProductCategoryKey has unique values: False

# %% [markdown]
# # Exploratory Data Analysis addressing data quality issues.

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Customers;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0        11000    MR.        JON     YANG  1966-04-08             M      M
# 1        11001    MR.     EUGENE    HUANG  1965-05-14             S      M
# 2        11002    MR.      RUBEN   TORRES  1965-08-12             M      M
# 3        11003    MS.    CHRISTY      ZHU  1968-02-15             S      F
# 4        11004   MRS.  ELIZABETH  JOHNSON  1968-08-08             S      F
#
#                      EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@adventure-works.com      $90,000              2      Bachelors
# 1    eugene10@adventure-works.com      $60,000              3      Bachelors
# 2     ruben35@adventure-works.com      $60,000              3      Bachelors
# 3   christy12@adventure-works.com      $70,000              0      Bachelors
# 4  elizabeth5@adventure-works.com      $80,000              5      Bachelors
#
#      Occupation HomeOwner
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Prefix          18148 non-null  object
#  2   FirstName       18148 non-null  object
#  3   LastName        18148 non-null  object
#  4   BirthDate       18148 non-null  object
#  5   MaritalStatus   18148 non-null  object
#  6   Gender          18148 non-null  object
#  7   EmailAddress    18148 non-null  object
#  8   AnnualIncome    18148 non-null  object
#  9   TotalChildren   18148 non-null  int64
#  10  EducationLevel  18148 non-null  object
#  11  Occupation      18148 non-null  object
#  12  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1.8+ MB
# None

# %%
print(df.describe())
# Out:
#         CustomerKey  TotalChildren
# count  18148.000000   18148.000000
# mean   20247.470465       1.843619
# std     5336.245656       1.613203
# min    11000.000000       0.000000
# 25%    15626.750000       0.000000
# 50%    20252.500000       2.000000
# 75%    24868.250000       3.000000
# max    29483.000000       5.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

#Output shows that the majority of customers do not have children
#Output also shows that the CustomerKey ranges from 11000 to 29500.

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Sales_2015;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  1/1/2015   9/21/2001     SO45080         332        14657             1
# 1  1/1/2015   12/5/2001     SO45079         312        29255             4
# 2  1/1/2015  10/29/2001     SO45082         350        11455             9
# 3  1/1/2015  11/16/2001     SO45081         338        26782             6
# 4  1/2/2015  12/15/2001     SO45083         312        14947            10
#
#    OrderLineItem  OrderQuantity
# 0              1              1
# 1              1              1
# 2              1              1
# 3              1              1
# 4              1              1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      2630 non-null   object
#  1   StockDate      2630 non-null   object
#  2   OrderNumber    2630 non-null   object
#  3   ProductKey     2630 non-null   int64
#  4   CustomerKey    2630 non-null   int64
#  5   TerritoryKey   2630 non-null   int64
#  6   OrderLineItem  2630 non-null   int64
#  7   OrderQuantity  2630 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 164.5+ KB
# None

# %%
print(df.describe())
# Out:
#         ProductKey   CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity
# count  2630.000000   2630.000000   2630.000000         2630.0         2630.0
# mean    344.180608  18344.052471      6.587833            1.0            1.0
# std      26.288429   5567.047291      2.915261            0.0            0.0
# min     310.000000  11090.000000      1.000000            1.0            1.0
# 25%     314.000000  13118.250000      4.000000            1.0            1.0
# 50%     348.000000  16828.500000      8.000000            1.0            1.0
# 75%     370.000000  22859.250000      9.000000            1.0            1.0
# max     389.000000  29481.000000     10.000000            1.0            1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

#Output shows that the product with the ID/KEY "310" was bought the most.

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Sales_2016;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#     OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  01/01/2016  10/17/2002     SO48797         385        14335             1
# 1  01/01/2016   9/30/2002     SO48802         383        24923             9
# 2  01/01/2016  11/29/2002     SO48801         326        15493             1
# 3  01/01/2016  11/16/2002     SO48799         352        26708             4
# 4  01/01/2016  12/16/2002     SO48798         369        23332             9
#
#    OrderLineItem  OrderQuantity
# 0              1              1
# 1              1              1
# 2              1              1
# 3              1              1
# 4              1              1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23935 entries, 0 to 23934
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      23935 non-null  object
#  1   StockDate      23935 non-null  object
#  2   OrderNumber    23935 non-null  object
#  3   ProductKey     23935 non-null  int64
#  4   CustomerKey    23935 non-null  int64
#  5   TerritoryKey   23935 non-null  int64
#  6   OrderLineItem  23935 non-null  int64
#  7   OrderQuantity  23935 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 1.5+ MB
# None

# %%
print(df.describe())
# Out:
#          ProductKey   CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity
# count  23935.000000  23935.000000  23935.000000   23935.000000   23935.000000
# mean     440.139837  18562.950783      6.275872       1.901817       1.513683
# std      117.340544   5478.596821      2.961307       1.014709       0.616046
# min      214.000000  11000.000000      1.000000       1.000000       1.000000
# 25%      362.000000  13555.500000      4.000000       1.000000       1.000000
# 50%      479.000000  17813.000000      7.000000       2.000000       1.000000
# 75%      529.000000  23137.000000      9.000000       2.000000       2.000000
# max      606.000000  29483.000000     10.000000       8.000000       3.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Sales_2017;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#     OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  01/01/2017  12/13/2003     SO61285         529        23791             1
# 1  01/01/2017   9/24/2003     SO61285         214        23791             1
# 2  01/01/2017  09/04/2003     SO61285         540        23791             1
# 3  01/01/2017   9/28/2003     SO61301         529        16747             1
# 4  01/01/2017  10/21/2003     SO61301         377        16747             1
#
#    OrderLineItem  OrderQuantity
# 0              2              2
# 1              3              1
# 2              1              1
# 3              2              2
# 4              1              1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29481 entries, 0 to 29480
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      29481 non-null  object
#  1   StockDate      29481 non-null  object
#  2   OrderNumber    29481 non-null  object
#  3   ProductKey     29481 non-null  int64
#  4   CustomerKey    29481 non-null  int64
#  5   TerritoryKey   29481 non-null  int64
#  6   OrderLineItem  29481 non-null  int64
#  7   OrderQuantity  29481 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 1.8+ MB
# None

# %%
print(df.describe())
# Out:
#          ProductKey   CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity
# count  29481.000000  29481.000000  29481.000000   29481.000000   29481.000000
# mean     446.461382  19116.104406      6.207727       1.984804       1.537058
# std      121.027611   5329.153213      2.957099       1.032695       0.617249
# min      214.000000  11001.000000      1.000000       1.000000       1.000000
# 25%      381.000000  14551.000000      4.000000       1.000000       1.000000
# 50%      480.000000  18362.000000      7.000000       2.000000       1.000000
# 75%      530.000000  23701.000000      9.000000       3.000000       2.000000
# max      606.000000  29480.000000     10.000000       8.000000       3.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Products;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#    ProductKey  ProductSubcategoryKey ProductSKU              ProductName  \
# 0         214                     31  HL-U509-R    Sport-100 Helmet, Red
# 1         215                     31    HL-U509  Sport-100 Helmet, Black
# 2         218                     23  SO-B909-M   Mountain Bike Socks, M
# 3         219                     23  SO-B909-L   Mountain Bike Socks, L
# 4         220                     31  HL-U509-B   Sport-100 Helmet, Blue
#
#              ModelName                                 ProductDescription  \
# 0            Sport-100  Universal fit, well-vented, lightweight , snap...
# 1            Sport-100  Universal fit, well-vented, lightweight , snap...
# 2  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 3  Mountain Bike Socks  Combination of natural and synthetic fibers st...
# 4            Sport-100  Universal fit, well-vented, lightweight , snap...
#
#   ProductColor ProductSize ProductStyle  ProductCost  ProductPrice
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             293 non-null    int64
#  1   ProductSubcategoryKey  293 non-null    int64
#  2   ProductSKU             293 non-null    object
#  3   ProductName            293 non-null    object
#  4   ModelName              293 non-null    object
#  5   ProductDescription     293 non-null    object
#  6   ProductColor           293 non-null    object
#  7   ProductSize            293 non-null    object
#  8   ProductStyle           293 non-null    object
#  9   ProductCost            293 non-null    float64
#  10  ProductPrice           293 non-null    float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 25.3+ KB
# None

# %%
print(df.describe())
# Out:
#        ProductKey  ProductSubcategoryKey  ProductCost  ProductPrice
# count  293.000000             293.000000   293.000000    293.000000
# mean   441.552901              12.283276   413.661009    714.437357
# std    108.064327               9.892831   517.611849    872.157258
# min    214.000000               1.000000     0.856500      2.290000
# 25%    354.000000               2.000000    31.724400     63.500000
# 50%    457.000000              12.000000   199.375700    333.420000
# 75%    533.000000              17.000000   601.743700   1003.910000
# max    606.000000              37.000000  2171.294200   3578.270000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
# Query the data from a table
query = "SELECT * FROM merged_AdventuresWorks_sales;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  TerritoryKey  \
# 0  1/1/2015   9/21/2001     SO45080         332        14657             1
# 1  1/1/2015   12/5/2001     SO45079         312        29255             4
# 2  1/1/2015  10/29/2001     SO45082         350        11455             9
# 3  1/1/2015  11/16/2001     SO45081         338        26782             6
# 4  1/2/2015  12/15/2001     SO45083         312        14947            10
#
#    OrderLineItem  OrderQuantity  ROW_ID
# 0              1              1       1
# 1              1              1       2
# 2              1              1       3
# 3              1              1       4
# 4              1              1       5

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56046 entries, 0 to 56045
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderDate      56046 non-null  object
#  1   StockDate      56046 non-null  object
#  2   OrderNumber    56046 non-null  object
#  3   ProductKey     56046 non-null  int64
#  4   CustomerKey    56046 non-null  int64
#  5   TerritoryKey   56046 non-null  int64
#  6   OrderLineItem  56046 non-null  int64
#  7   OrderQuantity  56046 non-null  int64
#  8   ROW_ID         56046 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 3.8+ MB
# None

# %%
print(df.describe())
# Out:
#          ProductKey   CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity  \
# count  56046.000000  56046.000000  56046.000000   56046.000000   56046.000000
# mean     438.962103  18843.645559      6.254666       1.903151       1.501873
# std      118.612352   5412.449843      2.958005       1.021006       0.612379
# min      214.000000  11000.000000      1.000000       1.000000       1.000000
# 25%      360.000000  14016.000000      4.000000       1.000000       1.000000
# 50%      479.000000  18157.000000      7.000000       2.000000       1.000000
# 75%      529.000000  23425.750000      9.000000       2.000000       2.000000
# max      606.000000  29483.000000     10.000000       8.000000       3.000000
#
#             ROW_ID
# count  56046.00000
# mean   28023.50000
# std    16179.23093
# min        1.00000
# 25%    14012.25000
# 50%    28023.50000
# 75%    42034.75000
# max    56046.00000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
# Query the data from a table
query = "SELECT * FROM AdventureWorks_Returns;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   ReturnDate  TerritoryKey  ProductKey  ReturnQuantity
# 0  1/18/2015             9         312               1
# 1  1/18/2015            10         310               1
# 2  1/21/2015             8         346               1
# 3  1/22/2015             4         311               1
# 4   2/2/2015             6         312               1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1809 entries, 0 to 1808
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ReturnDate      1809 non-null   object
#  1   TerritoryKey    1809 non-null   int64
#  2   ProductKey      1809 non-null   int64
#  3   ReturnQuantity  1809 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 56.7+ KB
# None

# %%
print(df.describe())
# Out:
#        TerritoryKey   ProductKey  ReturnQuantity
# count   1809.000000  1809.000000     1809.000000
# mean       6.259812   443.460475        1.010503
# std        2.948103   115.326651        0.101973
# min        1.000000   214.000000        1.000000
# 25%        4.000000   369.000000        1.000000
# 50%        7.000000   479.000000        1.000000
# 75%        9.000000   529.000000        1.000000
# max       10.000000   606.000000        2.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
# Query the data from a table
query = "SELECT * FROM Merged_AdventureWorks_DataandAdventureWorks_Products;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  CustomerKey  TerritoryKey  OrderLineItem  \
# 0  1/1/2015   9/21/2001     SO45080        14657             1              1
# 1  1/1/2015   12/5/2001     SO45079        29255             4              1
# 2  1/1/2015  10/29/2001     SO45082        11455             9              1
# 3  1/1/2015  11/16/2001     SO45081        26782             6              1
# 4  1/2/2015  12/15/2001     SO45083        14947            10              1
#
#    OrderQuantity  ROW_ID  ProductSubcategoryKey  ProductSKU  \
# 0              1       1                      2  BK-R50B-58
# 1              1       2                      2  BK-R93R-48
# 2              1       3                      1  BK-M82B-44
# 3              1       4                      2  BK-R50B-44
# 4              1       5                      2  BK-R93R-48
#
#               ProductName     ModelName  \
# 0      Road-650 Black, 58      Road-650
# 1        Road-150 Red, 48      Road-150
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56046 entries, 0 to 56045
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderDate              56046 non-null  object
#  1   StockDate              56046 non-null  object
#  2   OrderNumber            56046 non-null  object
#  3   CustomerKey            56046 non-null  int64
#  4   TerritoryKey           56046 non-null  int64
#  5   OrderLineItem          56046 non-null  int64
#  6   OrderQuantity          56046 non-null  int64
#  7   ROW_ID                 56046 non-null  int64
#  8   ProductSubcategoryKey  56046 non-null  int64
#  9   ProductSKU             56046 non-null  object
#  10  ProductName            56046 non-null  object
#  11  ModelName              56046 non-null  object
#  12  ProductDescription     56046 non-null  object
#  13  ProductColor           56046 non-null  object
# ...

# %%
print(df.describe())
# Out:
#         CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity       ROW_ID  \
# count  56046.000000  56046.000000   56046.000000   56046.000000  56046.00000
# mean   18843.645559      6.254666       1.903151       1.501873  28023.50000
# std     5412.449843      2.958005       1.021006       0.612379  16179.23093
# min    11000.000000      1.000000       1.000000       1.000000      1.00000
# 25%    14016.000000      4.000000       1.000000       1.000000  14012.25000
# 50%    18157.000000      7.000000       2.000000       1.000000  28023.50000
# 75%    23425.750000      9.000000       2.000000       2.000000  42034.75000
# max    29483.000000     10.000000       8.000000       3.000000  56046.00000
#
#        ProductSubcategoryKey   ProductCost  ProductPrice
# count           56046.000000  56046.000000  56046.000000
# mean               23.412982    255.750403    438.969347
# std                13.493235    496.192920    838.650049
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
# Query the data from a table
query = "SELECT * FROM Merged_AdventureWorks_Data_ProductsandAdventureWorks_Product_Subcategories;"
df = pd.read_sql_query(query,conn)

print(df.head())
# Out:
#   OrderDate   StockDate OrderNumber  CustomerKey  TerritoryKey  OrderLineItem  \
# 0  1/1/2015   9/21/2001     SO45080        14657             1              1
# 1  1/1/2015   12/5/2001     SO45079        29255             4              1
# 2  1/1/2015  10/29/2001     SO45082        11455             9              1
# 3  1/1/2015  11/16/2001     SO45081        26782             6              1
# 4  1/2/2015  12/15/2001     SO45083        14947            10              1
#
#    OrderQuantity  ROW_ID  ProductSKU             ProductName     ModelName  \
# 0              1       1  BK-R50B-58      Road-650 Black, 58      Road-650
# 1              1       2  BK-R93R-48        Road-150 Red, 48      Road-150
# 2              1       3  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3              1       4  BK-R50B-44      Road-650 Black, 44      Road-650
# 4              1       5  BK-R93R-48        Road-150 Red, 48      Road-150
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56046 entries, 0 to 56045
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderDate           56046 non-null  object
#  1   StockDate           56046 non-null  object
#  2   OrderNumber         56046 non-null  object
#  3   CustomerKey         56046 non-null  int64
#  4   TerritoryKey        56046 non-null  int64
#  5   OrderLineItem       56046 non-null  int64
#  6   OrderQuantity       56046 non-null  int64
#  7   ROW_ID              56046 non-null  int64
#  8   ProductSKU          56046 non-null  object
#  9   ProductName         56046 non-null  object
#  10  ModelName           56046 non-null  object
#  11  ProductDescription  56046 non-null  object
#  12  ProductColor        56046 non-null  object
#  13  ProductSize         56046 non-null  object
#  14  ProductStyle        56046 non-null  object
# ...

# %%
print(df.describe())
# Out:
#         CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity       ROW_ID  \
# count  56046.000000  56046.000000   56046.000000   56046.000000  56046.00000
# mean   18843.645559      6.254666       1.903151       1.501873  28023.50000
# std     5412.449843      2.958005       1.021006       0.612379  16179.23093
# min    11000.000000      1.000000       1.000000       1.000000      1.00000
# 25%    14016.000000      4.000000       1.000000       1.000000  14012.25000
# 50%    18157.000000      7.000000       2.000000       1.000000  28023.50000
# 75%    23425.750000      9.000000       2.000000       2.000000  42034.75000
# max    29483.000000     10.000000       8.000000       3.000000  56046.00000
#
#         ProductCost  ProductPrice  ProductCategoryKey
# count  56046.000000  56046.000000        56046.000000
# mean     255.750403    438.969347            3.102576
# std      496.192920    838.650049            1.258273
# min        0.856500      2.290000            1.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical columns
df.hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# The above tables depict the exploratory data analysis conducted to ensure proper data quality.
